# %% [markdown]
# ### Importing necessery `libraries`

# %%
from bs4 import BeautifulSoup
import requests
import json
import time
import pandas as pd

# %% [markdown]
# ### Defining `functions` to make `requests` and `pulling` data out of HTML

# %%
def MakingRequest(url: str) -> str:
    r = requests.get(URL)
    if r.status_code == 200:
        soup = BeautifulSoup(r.text, 'html.parser')
        print("\033[92m Request was successfully done. The status code: {}".format(r.status_code))
        USDollarExchangeRateTable = soup.find_all('td')
        Time = soup.find_all('span', class_="ratesTimestamp")[0].text
        USDollar = soup.find_all('th', class_='rtHeader rtHeaderCurr')[0].text
        ValueUSDollar = soup.find_all('th', class_='rtHeader rtHeaderValues')[0].text
        return USDollarExchangeRateTable, Time, USDollar, ValueUSDollar
    else:   
        print(f"\033[91m Request wasn't successfully done. The status code: {r.status_code}")


URL = 'https://www.x-rates.com/table/?from=USD&amount=1'
r = requests.get(URL)
soup = BeautifulSoup(r.text, 'html.parser')
MakingRequest(URL)
# Out:
#  Request was successfully done. The status code: 200
# ([<td>Euro</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=EUR">0.959582</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=EUR&amp;to=USD">1.042120</a></td>,
#   <td>British Pound</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=GBP">0.797881</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=GBP&amp;to=USD">1.253320</a></td>,
#   <td>Indian Rupee</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=INR">84.433636</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=INR&amp;to=USD">0.011844</a></td>,
#   <td>Australian Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=AUD">1.538015</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=AUD&amp;to=USD">0.650189</a></td>,
#   <td>Canadian Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CAD">1.397969</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CAD&amp;to=USD">0.715323</a></td>,
#   <td>Singapore Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=SGD">1.347842</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=SGD&amp;to=USD">0.741927</a></td>,
#   <td>Swiss Franc</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CHF">0.893812</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CHF&amp;to=USD">1.118804</a></td>,
#   <td>Malaysian Ringgit</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=MYR">4.467969</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=MYR&amp;to=USD">0.223815</a></td>,
#   <td>Japanese Yen</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=JPY">154.774685</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=JPY&amp;to=USD">0.006461</a></td>,
#   <td>Chinese Yuan Renminbi</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CNY">7.245414</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CNY&amp;to=USD">0.138018</a></td>,
#   <td>Argentine Peso</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=ARS">1003.870993</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=ARS&amp;to=USD">0.000996</a></td>,
#   <td>Australian Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=AUD">1.538015</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=AUD&amp;to=USD">0.650189</a></td>,
#   <td>Bahraini Dinar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=BHD">0.376000</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=BHD&amp;to=USD">2.659574</a></td>,
#   <td>Botswana Pula</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=BWP">13.636443</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=BWP&amp;to=USD">0.073333</a></td>,
#   <td>Brazilian Real</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=BRL">5.800766</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=BRL&amp;to=USD">0.172391</a></td>,
#   <td>Bruneian Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=BND">1.347842</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=BND&amp;to=USD">0.741927</a></td>,
#   <td>Bulgarian Lev</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=BGN">1.876780</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=BGN&amp;to=USD">0.532827</a></td>,
#   <td>Canadian Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CAD">1.397969</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CAD&amp;to=USD">0.715323</a></td>,
#   <td>Chilean Peso</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CLP">986.343388</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CLP&amp;to=USD">0.001014</a></td>,
#   <td>Chinese Yuan Renminbi</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CNY">7.245414</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CNY&amp;to=USD">0.138018</a></td>,
#   <td>Colombian Peso</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=COP">4418.747618</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=COP&amp;to=USD">0.000226</a></td>,
#   <td>Czech Koruna</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=CZK">24.322507</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=CZK&amp;to=USD">0.041114</a></td>,
#   <td>Danish Krone</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=DKK">7.157892</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=DKK&amp;to=USD">0.139706</a></td>,
#   <td>Euro</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=EUR">0.959582</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=EUR&amp;to=USD">1.042120</a></td>,
#   <td>Hong Kong Dollar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=HKD">7.784416</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=HKD&amp;to=USD">0.128462</a></td>,
#   <td>Hungarian Forint</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=HUF">394.979509</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=HUF&amp;to=USD">0.002532</a></td>,
#   <td>Icelandic Krona</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=
a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=TRY&amp;to=USD">0.028940</a></td>,
#   <td>Emirati Dirham</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=AED">3.672500</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=AED&amp;to=USD">0.272294</a></td>,
#   <td>British Pound</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=GBP">0.797881</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=GBP&amp;to=USD">1.253320</a></td>,
#   <td>Venezuelan Bolivar</td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=USD&amp;to=VEF">4652054.894421</a></td>,
#   <td class="rtRates"><a href="https://www.x-rates.com/graph/?from=VEF&amp;to=USD">0.000000</a></td>],
#  'Nov 23, 2024 09:37 UTC',
#  'US Dollar',
#  '1.00 USD')

# %% [markdown]
# ### Selecting data to process and create `List Comprehensions` based on it
# #### Selecting `US DOLLAR EXCHANGE RATES TABLE`

# %%
def SelectingData():
    r = requests.get(URL)
    soup = BeautifulSoup(r.text, 'html.parser')
    for Currency in soup.find_all('td'):
        print(Currency.text)
        
    currencies=soup.find_all('td')
    ListComprehension = [title.text for title in currencies]

    print(ListComprehension)

SelectingData()
# Out:
# Euro
# 0.959582
# 1.042120
# British Pound
# 0.797881
# 1.253320
# Indian Rupee
# 84.433636
# 0.011844
# Australian Dollar
# 1.538015
# 0.650189
# Canadian Dollar
# 1.397969
# 0.715323
# Singapore Dollar
# 1.347842
# 0.741927
# Swiss Franc
# 0.893812
# 1.118804
# Malaysian Ringgit
# 4.467969
# 0.223815
# Japanese Yen
# 154.774685
# 0.006461
# Chinese Yuan Renminbi
# 7.245414
# 0.138018
# Argentine Peso
# 1003.870993
# 0.000996
# Australian Dollar
# 1.538015
# 0.650189
# Bahraini Dinar
# 0.376000
# 2.659574
# Botswana Pula
# 13.636443
# 0.073333
# Brazilian Real
# 5.800766
# 0.172391
# Bruneian Dollar
# 1.347842
# 0.741927
# Bulgarian Lev
# 1.876780
# 0.532827
# Canadian Dollar
# 1.397969
# 0.715323
# Chilean Peso
# 986.343388
# 0.001014
# Chinese Yuan Renminbi
# 7.245414
# 0.138018
# Colombian Peso
# 4418.747618
# 0.000226
# Czech Koruna
# 24.322507
# 0.041114
# Danish Krone
# 7.157892
# 0.139706
# Euro
# 0.959582
# 1.042120
# Hong Kong Dollar
# 7.784416
# 0.128462
# Hungarian Forint
# 394.979509
# 0.002532
# Icelandic Krona
# 139.678739
# 0.007159
# Indian Rupee
# 84.433636
# 0.011844
# Indonesian Rupiah
# 15927.512506
# 0.000063
# Iranian Rial
# 42101.158121
# 0.000024
# Israeli Shekel
# 3.703017
# 0.270050
# Japanese Yen
# 154.774685
# 0.006461
# Kazakhstani Tenge
# 499.162701
# 0.002003
# South Korean Won
# 1403.979648
# 0.000712
# Kuwaiti Dinar
# 0.308035
# 3.246387
# Libyan Dinar
# 4.880332
# 0.204904
# Malaysian Ringgit
# 4.467969
# 0.223815
# Mauritian Rupee
# 46.693131
# 0.021416
# Mexican Peso
# 20.424251
# 0.048961
# Nepalese Rupee
# 135.157143
# 0.007399
# New Zealand Dollar
# 1.713675
# 0.583541
# Norwegian Krone
# 11.072674
# 0.090312
# Omani Rial
# 0.384957
# 2.597695
# Pakistani Rupee
# 277.691112
# 0.003601
# Philippine Peso
# 58.943686
# 0.016965
# Polish Zloty
# 4.162206
# 0.240257
# Qatari Riyal
# 3.640000
# 0.274725
# Romanian New Leu
# 4.777030
# 0.209335
.036392', '0.090609', 'Swiss Franc', '0.893812', '1.118804', 'Taiwan New Dollar', '32.589075', '0.030685', 'Thai Baht', '34.460930', '0.029018', 'Trinidadian Dollar', '6.781209', '0.147466', 'Turkish Lira', '34.553884', '0.028940', 'Emirati Dirham', '3.672500', '0.272294', 'British Pound', '0.797881', '1.253320', 'Venezuelan Bolivar', '4652054.894421', '0.000000']

# %% [markdown]
# ### Placing selected data to `List Comprehension`

# %%
def SavingDataToListComprehensionCurrency(currency: list) -> list:
    return [title.text for title in currency[::3]]

currencies=soup.find_all('td')
SavingDataToListComprehensionCurrency(currencies)
ListComprehensionCurrency = SavingDataToListComprehensionCurrency(currencies)
print(ListComprehensionCurrency)
# Out:
# ['Euro', 'British Pound', 'Indian Rupee', 'Australian Dollar', 'Canadian Dollar', 'Singapore Dollar', 'Swiss Franc', 'Malaysian Ringgit', 'Japanese Yen', 'Chinese Yuan Renminbi', 'Argentine Peso', 'Australian Dollar', 'Bahraini Dinar', 'Botswana Pula', 'Brazilian Real', 'Bruneian Dollar', 'Bulgarian Lev', 'Canadian Dollar', 'Chilean Peso', 'Chinese Yuan Renminbi', 'Colombian Peso', 'Czech Koruna', 'Danish Krone', 'Euro', 'Hong Kong Dollar', 'Hungarian Forint', 'Icelandic Krona', 'Indian Rupee', 'Indonesian Rupiah', 'Iranian Rial', 'Israeli Shekel', 'Japanese Yen', 'Kazakhstani Tenge', 'South Korean Won', 'Kuwaiti Dinar', 'Libyan Dinar', 'Malaysian Ringgit', 'Mauritian Rupee', 'Mexican Peso', 'Nepalese Rupee', 'New Zealand Dollar', 'Norwegian Krone', 'Omani Rial', 'Pakistani Rupee', 'Philippine Peso', 'Polish Zloty', 'Qatari Riyal', 'Romanian New Leu', 'Russian Ruble', 'Saudi Arabian Riyal', 'Singapore Dollar', 'South African Rand', 'Sri Lankan Rupee', 'Swedish Krona', 'Swiss Franc', 'Taiwan New Dollar', 'Thai Baht', 'Trinidadian Dollar', 'Turkish Lira', 'Emirati Dirham', 'British Pound', 'Venezuelan Bolivar']

# %%
def SavingDataToListComprehensionValues(ValuesOfCurrency: list) -> list:
    return [title.text for title in ValuesOfCurrency[1::3]]

Values = soup.find_all('td')
ListComprehensionValuesOfCurrency = SavingDataToListComprehensionValues(Values)
print(ListComprehensionValuesOfCurrency)
# Out:
# ['0.959582', '0.797881', '84.433636', '1.538015', '1.397969', '1.347842', '0.893812', '4.467969', '154.774685', '7.245414', '1003.870993', '1.538015', '0.376000', '13.636443', '5.800766', '1.347842', '1.876780', '1.397969', '986.343388', '7.245414', '4418.747618', '24.322507', '7.157892', '0.959582', '7.784416', '394.979509', '139.678739', '84.433636', '15927.512506', '42101.158121', '3.703017', '154.774685', '499.162701', '1403.979648', '0.308035', '4.880332', '4.467969', '46.693131', '20.424251', '135.157143', '1.713675', '11.072674', '0.384957', '277.691112', '58.943686', '4.162206', '3.640000', '4.777030', '104.320073', '3.750000', '1.347842', '18.115350', '291.142987', '11.036392', '0.893812', '32.589075', '34.460930', '6.781209', '34.553884', '3.672500', '0.797881', '4652054.894421']

# %% [markdown]
# ### Converting `List Comprehension` to `Dictionary`

# %%
def ConvertingListComprehensionToDictionary(Currency: list, Value: list) -> dict:
    my_dict = {Currency[i]: Value[i] for i in range(len(Currency))}
    return my_dict

DictionaryDataCurrencyValues = ConvertingListComprehensionToDictionary(ListComprehensionCurrency,ListComprehensionValuesOfCurrency)
ConvertingListComprehensionToDictionary(ListComprehensionCurrency,ListComprehensionValuesOfCurrency)
# Out:
# {'Euro': '0.959582',
#  'British Pound': '0.797881',
#  'Indian Rupee': '84.433636',
#  'Australian Dollar': '1.538015',
#  'Canadian Dollar': '1.397969',
#  'Singapore Dollar': '1.347842',
#  'Swiss Franc': '0.893812',
#  'Malaysian Ringgit': '4.467969',
#  'Japanese Yen': '154.774685',
#  'Chinese Yuan Renminbi': '7.245414',
#  'Argentine Peso': '1003.870993',
#  'Bahraini Dinar': '0.376000',
#  'Botswana Pula': '13.636443',
#  'Brazilian Real': '5.800766',
#  'Bruneian Dollar': '1.347842',
#  'Bulgarian Lev': '1.876780',
#  'Chilean Peso': '986.343388',
#  'Colombian Peso': '4418.747618',
#  'Czech Koruna': '24.322507',
#  'Danish Krone': '7.157892',
#  'Hong Kong Dollar': '7.784416',
#  'Hungarian Forint': '394.979509',
#  'Icelandic Krona': '139.678739',
#  'Indonesian Rupiah': '15927.512506',
#  'Iranian Rial': '42101.158121',
#  'Israeli Shekel': '3.703017',
#  'Kazakhstani Tenge': '499.162701',
#  'South Korean Won': '1403.979648',
#  'Kuwaiti Dinar': '0.308035',
#  'Libyan Dinar': '4.880332',
#  'Mauritian Rupee': '46.693131',
#  'Mexican Peso': '20.424251',
#  'Nepalese Rupee': '135.157143',
#  'New Zealand Dollar': '1.713675',
#  'Norwegian Krone': '11.072674',
#  'Omani Rial': '0.384957',
#  'Pakistani Rupee': '277.691112',
#  'Philippine Peso': '58.943686',
#  'Polish Zloty': '4.162206',
#  'Qatari Riyal': '3.640000',
#  'Romanian New Leu': '4.777030',
#  'Russian Ruble': '104.320073',
#  'Saudi Arabian Riyal': '3.750000',
#  'South African Rand': '18.115350',
#  'Sri Lankan Rupee': '291.142987',
#  'Swedish Krona': '11.036392',
#  'Taiwan New Dollar': '32.589075',
#  'Thai Baht': '34.460930',
#  'Trinidadian Dollar': '6.781209',
#  'Turkish Lira': '34.553884',
#  'Emirati Dirham': '3.672500',
#  'Venezuelan Bolivar': '4652054.894421'}

# %% [markdown]
# ### Saving `dictionary` to `JSON` file

# %%
def SaveToJSONfile(data: dict) -> json:
    timestr = time.strftime("%d-%m-%Y")
    try:
        with open(timestr + '-' +'US_DOLLAR_EXCHANGE_RATES_TABLE.json', 'w') as file:
                json.dump(data, file)
    except FileNotFoundError as ex:
        print(ex)


SaveToJSONfile(DictionaryDataCurrencyValues)

# %% [markdown]
# ### Saving `JSON` file to `DataFrame`

# %%
def ConvertingDictToJSON(datadict: dict) -> json:
    JSONUSDollarExchangeRatesTable = json.dumps(datadict)
    JSONUSDollarExchangeRatesTable
    dataUSDollarExchangeRatesTable = json.loads(JSONUSDollarExchangeRatesTable) 
    return dataUSDollarExchangeRatesTable

JSONCurrencyValues = ConvertingDictToJSON(DictionaryDataCurrencyValues)
ConvertingDictToJSON(DictionaryDataCurrencyValues)
# Out:
# {'Euro': '0.959582',
#  'British Pound': '0.797881',
#  'Indian Rupee': '84.433636',
#  'Australian Dollar': '1.538015',
#  'Canadian Dollar': '1.397969',
#  'Singapore Dollar': '1.347842',
#  'Swiss Franc': '0.893812',
#  'Malaysian Ringgit': '4.467969',
#  'Japanese Yen': '154.774685',
#  'Chinese Yuan Renminbi': '7.245414',
#  'Argentine Peso': '1003.870993',
#  'Bahraini Dinar': '0.376000',
#  'Botswana Pula': '13.636443',
#  'Brazilian Real': '5.800766',
#  'Bruneian Dollar': '1.347842',
#  'Bulgarian Lev': '1.876780',
#  'Chilean Peso': '986.343388',
#  'Colombian Peso': '4418.747618',
#  'Czech Koruna': '24.322507',
#  'Danish Krone': '7.157892',
#  'Hong Kong Dollar': '7.784416',
#  'Hungarian Forint': '394.979509',
#  'Icelandic Krona': '139.678739',
#  'Indonesian Rupiah': '15927.512506',
#  'Iranian Rial': '42101.158121',
#  'Israeli Shekel': '3.703017',
#  'Kazakhstani Tenge': '499.162701',
#  'South Korean Won': '1403.979648',
#  'Kuwaiti Dinar': '0.308035',
#  'Libyan Dinar': '4.880332',
#  'Mauritian Rupee': '46.693131',
#  'Mexican Peso': '20.424251',
#  'Nepalese Rupee': '135.157143',
#  'New Zealand Dollar': '1.713675',
#  'Norwegian Krone': '11.072674',
#  'Omani Rial': '0.384957',
#  'Pakistani Rupee': '277.691112',
#  'Philippine Peso': '58.943686',
#  'Polish Zloty': '4.162206',
#  'Qatari Riyal': '3.640000',
#  'Romanian New Leu': '4.777030',
#  'Russian Ruble': '104.320073',
#  'Saudi Arabian Riyal': '3.750000',
#  'South African Rand': '18.115350',
#  'Sri Lankan Rupee': '291.142987',
#  'Swedish Krona': '11.036392',
#  'Taiwan New Dollar': '32.589075',
#  'Thai Baht': '34.460930',
#  'Trinidadian Dollar': '6.781209',
#  'Turkish Lira': '34.553884',
#  'Emirati Dirham': '3.672500',
#  'Venezuelan Bolivar': '4652054.894421'}

# %%
def CreateDataFrameFromJSON(json):
    dfUSDollarExchangeRates = pd.DataFrame.from_dict(json, orient="index")
    dfUSDollarExchangeRates.reset_index(inplace=True)
    dfUSDollarExchangeRates = dfUSDollarExchangeRates.set_axis(['Currency', 'Rate'], axis=1)
    USDollar =pd.DataFrame([{'Currency':'US Dollar', 'Rate':'1.0'}]) 
    dfUSDollarExchangeRates = pd.concat([USDollar, dfUSDollarExchangeRates], ignore_index=True)
    today_ts = pd.Timestamp.today()
    dfUSDollarExchangeRates['LOADINGDATA'] = today_ts
    
    return dfUSDollarExchangeRates

dfUSDollarExchangeRates = CreateDataFrameFromJSON(JSONCurrencyValues)
CreateDataFrameFromJSON(JSONCurrencyValues)
# Out:
#                  Currency            Rate                LOADINGDATA
# 0               US Dollar             1.0 2024-11-23 10:37:48.300673
# 1                    Euro        0.959582 2024-11-23 10:37:48.300673
# 2           British Pound        0.797881 2024-11-23 10:37:48.300673
# 3            Indian Rupee       84.433636 2024-11-23 10:37:48.300673
# 50           Turkish Lira       34.553884 2024-11-23 10:37:48.300673
# 51         Emirati Dirham        3.672500 2024-11-23 10:37:48.300673
# 52     Venezuelan Bolivar  4652054.894421 2024-11-23 10:37:48.300673

# %% [markdown]
# ### Saving `DataFrame` to a `.csv` file

# %%
def SaveToCSVFile(dataframe):
    timestr = time.strftime("%d-%m-%Y")
    CSV = dataframe.to_csv(timestr + '-' + 'USDollarExchangeRates.csv')
    return CSV

SaveToCSVFile(dfUSDollarExchangeRates)

# %% [markdown]
# ### Selecting data to process and create `List Comprehensions` based on it
# #### Selecting a `Percent Change in the Last 24 hours`  table

# %%
def BrowsingData():
    NameOfTable = soup.find_all(class_="ratesChangetableHdr")[0].text
    PercentageChangeCurrency = soup.find_all(class_="currencyPairUL")[0].text
    return NameOfTable, PercentageChangeCurrency

BrowsingData()
# Out:
# ('Percent Change in the Last 24 Hours',
#  '\nEUR/USD+0.08107%USD/JPY+0.24864%GBP/USD+0.03791%USD/CHF+0.57852%USD/CAD-0.19164%EUR/JPY+0.32991%AUD/USD+0.20963%CNY/USD+0.04102%\n')

# %% [markdown]
# ### Saving selected data to `List Comprehension`

# %%
def ExtractingDataAndSaveItToListComprehension(data: str) -> list:
    return [PercentageCurrencyValue.text for PercentageCurrencyValue in data]

PercentageChangeCurrency = soup.find_all(class_="currencyPairUL")[0].find_all('li')

ConversionCurrencyPercentageChange = ExtractingDataAndSaveItToListComprehension(PercentageChangeCurrency)

ExtractingDataAndSaveItToListComprehension(PercentageChangeCurrency)
# Out:
# ['EUR/USD+0.08107%',
#  'USD/JPY+0.24864%',
#  'GBP/USD+0.03791%',
#  'USD/CHF+0.57852%',
#  'USD/CAD-0.19164%',
#  'EUR/JPY+0.32991%',
#  'AUD/USD+0.20963%',
#  'CNY/USD+0.04102%']

# %% [markdown]
# ### Selecting the part of `data` to split into two `Lists Comprehension`

# %%
def ExtractingConversionCurrency(conversioncurrency: str) -> list:
    return [str(ConversionCurrency)[:7:] for ConversionCurrency in conversioncurrency]
  
ConversionCurrency = ExtractingConversionCurrency(ConversionCurrencyPercentageChange)        
ExtractingConversionCurrency(ConversionCurrencyPercentageChange)
# Out:
# ['EUR/USD',
#  'USD/JPY',
#  'GBP/USD',
#  'USD/CHF',
#  'USD/CAD',
#  'EUR/JPY',
#  'AUD/USD',
#  'CNY/USD']

# %%
def ExtractingChangePercentage(changepercentage: str) -> list:
    return [PercentageValue.text for PercentageValue in changepercentage]

PercentageChange  = soup.find_all('span', {'class':['down','up']})
ChangePercentage = ExtractingChangePercentage(PercentageChange) 
ExtractingChangePercentage(PercentageChange)
# Out:
# ['+0.08107%',
#  '+0.24864%',
#  '+0.03791%',
#  '+0.57852%',
#  '-0.19164%',
#  '+0.32991%',
#  '+0.20963%',
#  '+0.04102%']

# %% [markdown]
# ### Creating `Dictionary` based on two `Lists Comprehension`

# %%
DictionaryConversionRateChangePercentage = ConvertingListComprehensionToDictionary(ConversionCurrency,ChangePercentage) 
ConvertingListComprehensionToDictionary(ConversionCurrency,ChangePercentage)
# Out:
# {'EUR/USD': '+0.08107%',
#  'USD/JPY': '+0.24864%',
#  'GBP/USD': '+0.03791%',
#  'USD/CHF': '+0.57852%',
#  'USD/CAD': '-0.19164%',
#  'EUR/JPY': '+0.32991%',
#  'AUD/USD': '+0.20963%',
#  'CNY/USD': '+0.04102%'}

# %% [markdown]
# ### Saving `Dictionary` data to a `JSON` file

# %%
def SaveToJSONfile(data: dict) -> json:
    timestr = time.strftime("%d-%m-%Y")
    try:
        with open(timestr + '-' +'PERCENT_CHANGE_IN_THE_LAST_24_HOURS.json', 'w') as file:
                json.dump(data, file)
    except FileNotFoundError as ex:
        print(ex)
        

SaveToJSONfile(DictionaryConversionRateChangePercentage)

# %% [markdown]
# ### Converting `Dictionary` to `JSON`

# %%
def ConvertingDictToJSON(datadict: dict) -> json:
    JSONUSDollarExchangeRatesTable = json.dumps(datadict)
    JSONUSDollarExchangeRatesTable
    dataUSDollarExchangeRatesTable = json.loads(JSONUSDollarExchangeRatesTable) 
    return dataUSDollarExchangeRatesTable

JSONConversionRateChangePercentage = ConvertingDictToJSON(DictionaryConversionRateChangePercentage)
ConvertingDictToJSON(DictionaryConversionRateChangePercentage)
# Out:
# {'EUR/USD': '+0.08107%',
#  'USD/JPY': '+0.24864%',
#  'GBP/USD': '+0.03791%',
#  'USD/CHF': '+0.57852%',
#  'USD/CAD': '-0.19164%',
#  'EUR/JPY': '+0.32991%',
#  'AUD/USD': '+0.20963%',
#  'CNY/USD': '+0.04102%'}

# %% [markdown]
# ### Creating `DataFrame` based on `JSON`

# %%
def CreateDataFrameFromJSONPercentageChange(json):
    dfPercentChangeIntheLast24Hours = pd.DataFrame.from_dict(json, orient="index")
    dfPercentChangeIntheLast24Hours.reset_index(inplace=True)
    dfPercentChangeIntheLast24Hours = dfPercentChangeIntheLast24Hours.set_axis(['ConversionCurrency', 'PercentChange'], axis=1)
    today_ts = pd.Timestamp.today()
    dfPercentChangeIntheLast24Hours['LOADINGDATA'] = today_ts
    dfPercentChangeIntheLast24Hours     

    return dfPercentChangeIntheLast24Hours

dfPercentChangeIntheLast24Hours = CreateDataFrameFromJSONPercentageChange(JSONConversionRateChangePercentage)
CreateDataFrameFromJSONPercentageChange(JSONConversionRateChangePercentage)
# Out:
#   ConversionCurrency PercentChange                LOADINGDATA
# 0            EUR/USD     +0.08107% 2024-11-23 10:37:48.501911
# 1            USD/JPY     +0.24864% 2024-11-23 10:37:48.501911
# 2            GBP/USD     +0.03791% 2024-11-23 10:37:48.501911
# 3            USD/CHF     +0.57852% 2024-11-23 10:37:48.501911
# 4            USD/CAD     -0.19164% 2024-11-23 10:37:48.501911
# 5            EUR/JPY     +0.32991% 2024-11-23 10:37:48.501911
# 6            AUD/USD     +0.20963% 2024-11-23 10:37:48.501911
# 7            CNY/USD     +0.04102% 2024-11-23 10:37:48.501911

# %% [markdown]
# ### Saving `DataFrame` to a `.csv` file

# %%
def SaveToCSVFile(dataframe):
    timestr = time.strftime("%d-%m-%Y")
    CSV = dataframe.to_csv(timestr + '-' + 'PercentChangeIntheLast24Hours.csv')
    return CSV

SaveToCSVFile(dfPercentChangeIntheLast24Hours)
